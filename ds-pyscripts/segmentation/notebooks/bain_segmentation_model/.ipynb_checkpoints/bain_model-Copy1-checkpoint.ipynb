# %%
#data and visuals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datetime


#modelling
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE, SMOTENC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import PolynomialFeatures

pd.options.display.max_rows = 4000

# %%
#user defined lists
segments = ["Cheap + Comfy","Cheap + Curious","Curious","Comfy","Craver","Caviar"]
segments2 = ["Assigned Segment." + i for i in segments]

bain_10questions = [
    'I always choose higher end hotels',
    'On vacation I pride myself on discovering new places and things my friends have not seen before',
    'I choose more expensive hotels and accommodations to make sure I get the best service and amenities',
    'It is important for me to be in a luxurious setting and to be pampered on vacation',
    'I like to immerse myself in the local culture when on vacation',
    'The difference between luxury and standard hotels just is not big enough to justify the cost',
    'I always pay more for a higher class of room on my vacations',
    'I would rather spend as little as possible on accommodations so I have more money to spend on other parts of my vacation',
    'I think spending more for unique experiences is part of what makes a vacation special',
    'I like to go on vacations that are off the beaten path'
]

# %%
#user defined functions

#Function: multi_pred_enricher
def multi_pred_enricher(preds):
    """
    Purpose: transform multi-output prediction array into dataframe with predicted Bain segment
    """
    preds = pd.DataFrame(preds)
    preds.columns = segments2
    preds = preds[segments2]
    preds['Assigned Segment'] = ""
    preds['Assigned Segment (Model Value)'] = 0
    for i in segments2:
        #Assign segment if resulting model value is the maximum resulting value
        preds.loc[:,'Assigned Segment'] = np.where(
            preds['Assigned Segment (Model Value)'] >= preds[i], preds['Assigned Segment'], i)
        preds.loc[:,'Assigned Segment (Model Value)'] = np.where(
            preds['Assigned Segment'] == i, preds[i], preds['Assigned Segment (Model Value)'])

    preds['Assigned Segment'] = preds['Assigned Segment'].map(lambda x: x.lstrip('Assigned Segment.'))   
    
    return preds

#Function: multi_pred_score_visualizer
def multi_pred_score_visualizer(actual, preds):
    score = np.mean(actual == preds)
    cm = metrics.confusion_matrix(actual, preds)
    plt.figure(figsize=(4,4))
    sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r'
               ,xticklabels = ["Caviar", "Cheap + Comfy","Cheap + Curious","Comfy","Craver","Curious"]
               ,yticklabels = ["Caviar", "Cheap + Comfy","Cheap + Curious","Comfy","Craver","Curious"]
               );
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Accuracy Score (test): {0}'.format(score.round(10))
    plt.suptitle(all_sample_title, size = 15);
    #plt.title('Accuracy Score (train): {0}'.format(train_score.round(10)), size = 11);
    plt.show()
    
    
def multi_feature_importance(model):
    # Plot feature importance
    feature_importance = model.feature_importances_
    # make importances relative to max importance
    feature_importance = 100.0 * (feature_importance / feature_importance.max())
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5
    plt.subplot(1, 2, 2)
    plt.barh(pos[-20:], feature_importance[sorted_idx][-20:], align='center')
    plt.yticks(pos[-20:], x_train_raw.columns[sorted_idx][-20:])
    plt.xlabel('Relative Importance')
    plt.title('Variable Importance')
    plt.show()

# %%
x_vars = pd.read_csv("../../data/bain_x_vars.csv")
y_vars = pd.read_csv("../../data/bain_y_vars.csv")

print("x_vars.shape:",x_vars.shape)
print("y_vars.shape:",y_vars.shape)
# Out:
# x_vars.shape: (616, 944)
# y_vars.shape: (616, 90)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_vars,
                                                    y_vars,
                                                    test_size=0.2, random_state=195)

# %%
x_train_raw = x_train
x_test_raw = x_test

train = pd.concat([x_train, y_train["Assigned Segment"]], axis = 1)
test = pd.concat([x_test, y_test["Assigned Segment"]], axis = 1)

#fill in missing data
imp = IterativeImputer(max_iter=10, random_state=0)
imp.fit(x_train)
x_train = imp.transform(x_train)
x_test = imp.transform(x_test)

print("Shape - x_train:",x_train.shape)
print("Shape - x_test:",x_test.shape)
print("Shape - y_train:",y_train.shape)
print("Shape - y_test:",y_test.shape)
# Out:
# Shape - x_train: (492, 944)
# Shape - x_test: (124, 944)
# Shape - y_train: (492, 90)
# Shape - y_test: (124, 90)

# %%
model = make_pipeline(IterativeImputer(max_iter=10, random_state=0),
                      RandomForestClassifier(random_state=195))

model.fit(x_train, y_train['Assigned Segment'])
predictions = model.predict(x_test)
multi_pred_score_visualizer(y_test['Assigned Segment'],predictions)
# Out:
# C:\Users\zmerritt\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
regr_rf = make_pipeline(IterativeImputer(max_iter=10, random_state=0),
                      RandomForestRegressor(
                          n_estimators=200, 
                          max_depth=25,
                          min_samples_leaf = 1,
                          random_state=195))

regr_rf.fit(x_train, y_train[segments2])
# Predict on new data
y_rf = regr_rf.predict(x_test)
y_rf = multi_pred_enricher(y_rf)
y_rf = np.array(y_rf['Assigned Segment'])
multi_pred_score_visualizer(y_test['Assigned Segment'],predictions)

# %%
model = make_pipeline(IterativeImputer(max_iter=10, random_state=0),
                      Lasso(alpha=1, 
                            max_iter = 200,
                            normalize = True,
                            fit_intercept=True))

model.fit(x_train, y_train[segments2])
# Predict on new data
y_rf = model.predict(x_test)
y_rf = multi_pred_enricher(y_rf)
y_rf = np.array(y_rf['Assigned Segment'])
multi_pred_score_visualizer(y_test['Assigned Segment'],y_rf)

# %%
pd.DataFrame(x_vars.iloc[:2,].T).reset_index()
# Out:
#                                                  index          0          1
# 0                          home_video_recording_acxiom          0          0
# 1                                   accessories_acxiom          0          0
# 2                                       aerobic_acxiom          0          0
# 3                            affairsandpolitics_acxiom          0          0
# 4                                  alcohol_wine_acxiom          0          0
# 5                              american_history_acxiom          0          0
# 6                                animal_welfare_acxiom          0          0
# 7                                      antiques_acxiom          0          0
# 8                                    appliances_acxiom          0          0
# 9                                           art_acxiom          1          0
# 10                              artistic_living_acxiom          0          0
# 11                                arts_antiques_acxiom          0          0
# 12                                  audio_books_acxiom          0          0
# 13                                   auto_parts_acxiom          0          0
# 14                                    auto_work_acxiom          0          0
# 15                                   automotive_acxiom          0          0
# 16                                     aviation_acxiom          0          0
# 17                            avid_collectibles_acxiom          0          0
# 18                          avid_music_listener_acxiom          1          1
# 19                                    baby_care_acxiom          0          0
# 20                                     baseball_acxiom          0          0
# 21                                   basketball_acxiom          0          0
# 22                             beauty_cosmetics_acxiom          0          0
# 23                                  bestsellers_acxiom          0          0
# 24                                       biking_acxiom          0          1
# 25                                  board_games_acxiom          0          0
# 26                                      boating_acxiom          0          1
# 27                                    boatowner_acxiom          0          0
# 28                                        books_acxiom          1          0
# 29                               broader_living_acxiom          0          0
# 30                                     buddhist_acxiom          0          0
# 31                              budget_watchers_acxiom          0          0
# 32                                     cable_tv_acxiom          0          0
# 33                                      camping_acxiom          0          0
# 34                           career_improvement_acxiom          0          0
# 35                                       casino_acxiom          0          0
# 36                                    cat_owner_acxiom          0          0
# 37                                     catholic_acxiom          0          1
# 38                                  celebrities_acxiom          0          0
# 39                                    charities_acxiom          0          1
# 40                                     children_acxiom          0          0
# 41                             children_product_acxiom          0          0
# 42                 children_support_financially_acxiom          0          0
# 43                                     chiphead_acxiom          0          0
# 44                                        coins_acxiom          0          0
# 45                                 collectibles_acxiom          0          0
# 46                        collectibles_antiques_acxiom          0          0
# 47                                common_living_acxiom          0          0
# 48                               computer_games_acxiom          0          0
# 49                                    computers_acxiom          0          1
# 50                                    computing_acxiom          0          0
# 51                        computing_home_office_acxiom          0          0
# 52                                 conservative_acxiom          0          0
# 53                         consumer_electronics_acxiom          1          1
# 54                                      contest_acxiom          0          0
# 55                                      cooking_acxiom          1          1
# 56                                    cosmetics_acxiom          0          0
# 57                              costume_jewelry_acxiom          0          0
# 58                                       crafts_acxiom          0          0
# 59                         creatures_of_comfort_acxiom          0          0
# 60                                       cruise_acxiom          0          0
# 61                    cruises_package_vacations_acxiom          0          0
# 62                                     cultural_acxiom          0          0
# 63                                   democratic_acxiom          0          0
# 64                                      dieting_acxiom          0          0
# 65                                   diy_living_acxiom          0          0
# 66                                    dog_owner_acxiom          1          0
# 67                              domestic_travel_acxiom          1          1
# 68                             eastern_orthodox_acxiom          0          0
# 69                             education_online_acxiom          0          0
# 70                        electronics_computers_acxiom          1          1
# 71                      environment_or_wildlife_acxiom          0          0
# 72                      environmental_home_care_acxiom          0          0
# 73                                   equestrian_acxiom          0          0
# 74                           ethiopian_orthodox_acxiom          0          0
# 75                                     exercise_acxiom          1          1
# 76                             family_vacations_acxiom          0          0
# 77                                      fashion_acxiom          0          0
# 78                         financial_newsletter_acxiom          1          0
# 79                               first_coasters_acxiom          0          0
# 80                                      fishing_acxiom          1          0
# 81                                      flowers_acxiom          0          0
# 82                                     football_acxiom          0          0
# 83                                    gardening_acxiom          1          0
# 84                                        gifts_acxiom          0          0
# 85                                         golf_acxiom          0          0
# 86                              gourmet_cooking_acxiom          1          1
# 87                                grandchildren_acxiom          0          0
# 88                               greek_orthodox_acxiom          0          0
# 89                               green_activist_acxiom          0          0
# 90                              green_investors_acxiom          0          1
# 91                          guns_and_ammunition_acxiom          0          0
# 92                           hands_on_believers_acxiom          0          0
# 93                                       health_acxiom          0          0
# 94                                health_beauty_acxiom          0          0
# 95                          high_end_appliances_acxiom          0          0
# 96                             high_tech_living_acxiom          0          0
# 97                                     highbrow_acxiom          0          0
# 98                                       hiking_acxiom          0          0
# 99                                        hindu_acxiom          0          0
# 100                                      hockey_acxiom          0          0
# 101                                holiday_item_acxiom          0          0
# 102                                   home_care_acxiom          0          0
# 103                                  home_decor_acxiom          0          0
# 104                            home_furnishings_acxiom          0          1
# 105                                 home_garden_acxiom          0          0
# 106                            home_improvement_acxiom          1          1
# 107                                 home_living_acxiom          0          0
# 108                                 home_office_acxiom          0          0
# 109                                 homeopathic_acxiom          0          1
# 110                                house_plants_acxiom          0          0
# 111                                     hunting_acxiom          0          0
# 112                               inspirational_acxiom          0          0
# 113                        international_travel_acxiom          1          0
# 114                                 internet_tv_acxiom          0          0
# 115                                     jewelry_acxiom          0          0
# 116                                      jewish_acxiom          0          0
# 117                                     jogging_acxiom          0          0
# 118                                    knitting_acxiom          0          0
# 119                                      laptop_acxiom          0          0
# 120                  learning_and_activity_toys_acxiom          0          0
# 121                                     liberal_acxiom          0          0
# 122                                  lifestyles_acxiom          0          0
# 123               lifestyles_interests_passions_acxiom          0          0
# 124                           living_in_the_now_acxiom          0          0
# 125                                     lottery_acxiom          0          0
# 126                             low_fat_cooking_acxiom          0          1
# 127                                     luggage_acxiom          0          0
# 128                                    lutheran_acxiom          0          0
# 129                                   magazines_acxiom          1          1
# 130                            membership_clubs_acxiom          0          0
# 131                                    military_acxiom          0          0
# 132                                      mormon_acxiom          0          0
# 133                            motorcycleracing_acxiom          0          0
# 134                                motorcycling_acxiom          0          0
# 135                             mountain_biking_acxiom          0          1
# 136                             movie_collector_acxiom          0          1
# 137                               movie_watcher_acxiom          0          0
# 138                                      movies_acxiom          1          1
# 139                                       music_acxiom          0          0
# 140                             music_collector_acxiom          0          0
# 141                                music_player_acxiom          1          0
# 142                         musical_instruments_acxiom          0          0
# 143                                      muslim_acxiom          0          0
# 144                                      nascar_acxiom          0          0
# 145                               natural_foods_acxiom          0          0
# 146                                  needlework_acxiom          0          0
# 147                                    no_party_acxiom          0          0
# 148                                     organic_acxiom          0          0
# 149                          outdoor_decorating_acxiom          0          0
# 150                                    outdoors_acxiom          1          1
# 151                                   parenting_acxiom          0          1
# 152                             performing_arts_acxiom          0          0
# 153                                   pet_owner_acxiom          1          0
# 154                                        pets_acxiom          0          0
# 155                                 photography_acxiom          0          1
# 156                                   political_acxiom          0          1
# 157                               power_boating_acxiom          0          0
# 158                                 pragmatists_acxiom          0          0
# 159                         professional_living_acxiom          0          0
# 160                                  protestant_acxiom          1          0
# 161                                     puzzles_acxiom          0          0
# 162                                     reading_acxiom          1          1
# 163                                   religious_acxiom          0          0
# 164                                  republican_acxiom          1          0
# 165                                     running_acxiom          0          0
# 166                                          rv_acxiom          0          0
# 167                                     sailing_acxiom          0          1
# 168                             science_fiction_acxiom          0          0
# 169                               science_space_acxiom          0          1
# 170                                scuba_diving_acxiom          0          0
# 171                            self_improvement_acxiom          0          0
# 172                                senior_needs_acxiom          0          0
# 173                                      sewing_acxiom          0          0
# 174                                      shinto_acxiom          0          0
# 175                                    shooting_acxiom          0          0
# 176                                        sikh_acxiom          0          0
# 177                             smoking_tobacco_acxiom          0          0
# 178                                 snow_skiing_acxiom          0          0
# 179                                      soccer_acxiom          0          0
# 180                                      sports_acxiom          0          0
# 181                          sports_and_leisure_acxiom          0          0
# 182                          sports_memorabilia_acxiom          0          0
# 183                               sporty_living_acxiom          0          0
# 184                                      stamps_acxiom          0          0
# 185                                  stationary_acxiom          0          0
# 186                         strange_and_unusual_acxiom          0          0
# 187                                 sweepstakes_acxiom          0          0
# 188                           tech_frontiersmen_acxiom          0          0
# 189                                tech_to_live_acxiom          0          0
# 190                          telecommunications_acxiom          0          0
# 191                                      tennis_acxiom          0          0
# 192                                     theater_acxiom          0          0
# 193                                        toys_acxiom          0          0
# 194                                      travel_acxiom          1          1
# 195                                   tv_sports_acxiom          0          0
# 196                                   unplugged_acxiom          0          0
# 197                              upscale_living_acxiom          0          0
# 198            value_priced_general_merchandise_acxiom          0          0
# 199                            vegetarian_foods_acxiom          0          0
# 200                                     veteran_acxiom          0          0
# 201                                 video_games_acxiom          0          0
# 202                                      videos_acxiom          0          0
# 203                                     walking_acxiom          0          0
# 204                                water_sports_acxiom          0          0
# 205                                    weaponry_acxiom          0          0
# 206                                  weightloss_acxiom          0          1
# 207                                 woodworking_acxiom          1          0
# 208                                        yoga_acxiom          0          0
# 209                                            mystery   0.123094   0.185413
# 210                                          adventure   0.198927  0.0462392
# 211                                              quirk   0.137974   0.121549
# 212                                              party  0.0387931   0.141918
# 213                                          glamorous   0.154103   0.259728
# 214                                               cool   0.191961   0.166482
# 215                                              chill   0.155148  0.0786706
# 216                       person_basicdemographics_age         62         74
# 217                  person_basicdemographics_deceased      False      False
# 218         person_basicdemographics_enteringadulthood      False      False
# 219         person_basicdemographics_lengthofresidence         12         15
# 220              person_basicdemographics_singleparent      False      False
# 221  household_basicdemographics_africanamericanpro...      False      False
# 222  household_basicdemographics_childnearhsgraduation      False      False
# 223        household_basicdemographics_childrenpresent      False      False
# 224     household_basicdemographics_estimatedincomemin     125000     125000
# 225     household_basicdemographics_estimatedincomemax          0          0
# 226            household_basicdemographics_generations          1          1
# 227      household_basicdemographics_lengthofresidence         12         15
# 228               household_basicdemographics_newmover      False      False
# 229               household_basicdemographics_newlywed      False      False
# 230         household_basicdemographics_numberofadults          2          2
# 231       household_basicdemographics_numberofchildren          0          0
# 232         household_basicdemographics_numberofpeople          2          2
# 233  household_basicdemographics_probableteendriver...      False      False
# 234  household_basicdemographics_probableteendriver...      False      False
# 235  household_basicdemographics_recentcollegegraduate      False      False
# 236          household_basicdemographics_recentdivorce      False      False
# 237  household_basicdemographics_senioradultinhouse...      False      False
# 238           household_basicdemographics_singleparent      False      False
# 239          household_basicdemographics_sohoindicator      False      False
# 240                household_basicdemographics_veteran      False      False
# 241           household_basicdemographics_workingwoman      False       True
# 242             household_basicdemographics_youngadult      False      False
# 243  household_basicdemographics_youngadultinhousehold      False      False
# 244              causesandvolunteer_communitycharities      False      False
# 245             causesandvolunteer_environmentalissues      False      False
# 246                        causesandvolunteer_donation      False      False
# 247            spending_averagedaysbetweenonlineorders          0          9
# 248               spending_averagedollaramountperorder          0          0
# 249            spending_averagedollaramountperpurchase          0         81
# 250                     spending_categoryspend_apparel          0        163
# 251             spending_categoryspend_artsandantiques          0          0
# 252                  spending_categoryspend_automotive          0          0
# 253                      spending_categoryspend_beauty          0          0
# 254                       spending_categoryspend_books          0          0
# 255           spending_categoryspend_childrensproducts          0          0
# 256                spending_categoryspend_collectibles          0          0
# 257         spending_categoryspend_computinghomeoffice          0          0
# 258               spending_categoryspend_craftshobbies          0          0
# 259                 spending_categoryspend_electronics          0          0
# 260             spending_categoryspend_foodandbeverage          0          0
# 261                   spending_categoryspend_furniture          0       3926
# 262                      spending_categoryspend_garden          0          0
# 263          spending_categoryspend_generalmerchandise          0          0
# 264                       spending_categoryspend_gifts          0          0
# 265                      spending_categoryspend_health          0          0
# 266                spending_categoryspend_holidayitems          0          0
# 267                    spending_categoryspend_homecare          0          0
# 268             spending_categoryspend_homefurnishings          0          0
# 269                  spending_categoryspend_housewares          0          0
# 270                     spending_categoryspend_jewelry          0          0
# 271                      spending_categoryspend_linens          0          0
# 272                       spending_categoryspend_music          0          0
# 273                     spending_categoryspend_novelty          0          0
# 274                       spending_categoryspend_other          0          0
# 275                spending_categoryspend_personalcare          0          0
# 276                        spending_categoryspend_pets          0          0
# 277               spending_categoryspend_photoandvideo          0          0
# 278               spending_categoryspend_specialtyfood          0          0
# 279              spending_categoryspend_specialtygifts          0          0
# 280            spending_categoryspend_sportsandleisure          0          0
# 281                  spending_categoryspend_stationery          0          0
# 282                      spending_categoryspend_travel          0          0
# 283               spending_categoryspend_videosanddvds          0          0
# 284                            spending_offlinedollars         65       4564
# 285                             spending_onlinedollars          0          0
# 286                              spending_onlineorders          0          0
# 287                            spending_travelspendmin          0          0
# 288                            spending_travelspendmax          0          0
# 289                        spending_totalonlinedollars          0        163
# 290          spending_totalonlineorder_dollars1000plus          0          0
# 291          spending_totalonlineorder_dollars100to250          0          1
# 292          spending_totalonlineorder_dollars250to500          0          0
# 293         spending_totalonlineorder_dollars500to1000          0          0
# 294           spending_totalonlineorder_dollars50to100          0          0
# 295           spending_totalonlineorder_dollarsunder50          0          1
# 296                    spending_totalonlineorder_total          0          2
# 297                spending_weekssincefirstonlineorder          0        227
# 298                 spending_weekssincelastonlineorder          0        226
# 299                etechdemographics_assimilationindex          0          0
# 300                mediaconsumption_mailorderresponder       True       True
# 301                     mediaconsumption_textmessaging      False      False
# 302  marketindicespopulationdemographicsage_age18pl...       48.3       51.2
# 303  marketindicespopulationdemographicsage_age18pl...       45.8         49
# 304  marketindicespopulationdemographicsage_age18pl...          3          2
# 305  marketindicespopulationdemographicsage_age18pl...         31          3
# 306  marketindicespopulationdemographicsage_age18pl...         14         23
# 307  marketindicespopulationdemographicsage_age18pl...         19         44
# 308  marketindicespopulationdemographicsage_age18pl...         13          8
# 309  marketindicespopulationdemographicsage_age18pl...         11         19
# 310  marketindicespopulationdemographicsage_age18pl...          9          1
# 311  marketindicespopulationdemographicsage_age25pl...       49.1       51.9
# 312  marketindicespopulationdemographicsage_age25pl...       46.5       49.2
# 313  marketindicespopulationdemographicsage_ageblac...         74          0
# 314  marketindicespopulationdemographicsage_ageblac...          4          0
# 315  marketindicespopulationdemographicsage_ageblac...         22          0
# 316  marketindicespopulationdemographicsage_agehisp...         45         31
# 317  marketindicespopulationdemographicsage_agehisp...          4         12
# 318  marketindicespopulationdemographicsage_agehisp...         51         57
# 319  marketindicespopulationdemographicsage_total_a...       38.6       37.4
# 320  marketindicespopulationdemographicsage_total_m...       36.7       44.6
# 321  marketindicespopulationdemographicsage_total_p...         62         53
# 322  marketindicespopulationdemographicsage_total_p...         15         14
# 323  marketindicespopulationdemographicsage_total_p...         23         33
# 324  marketindicespopulationdemographicsage_white_p...         64         56
# 325  marketindicespopulationdemographicsage_white_p...         17         18
# 326  marketindicespopulationdemographicsage_white_p...         19         26
# 327  marketindicespopulationdemographicsage_househo...         13         13
# 328  marketindicespopulationdemographicsage_househo...         15         19
# 329  marketindicespopulationdemographicsage_househo...         13          8
# 330  marketindicespopulationdemographicsage_househo...         23         12
# 331  marketindicespopulationdemographicsage_househo...         10          4
# 332  marketindicespopulationdemographicsage_househo...         28         49
# 333  marketindicespopulationdemographicsage_househo...         12         25
# 334  marketindicespopulationdemographicsage_househo...         16         24
# 335  marketindicespopulationdemographicsage_househo...         21          7
# 336          shoppingandpurchasechannel_mailorderbuyer       True       True
# 337          shoppingandpurchasechannel_mailorderdonor      False      False
# 338  shoppingandpurchasechannel_onlinepurchaseindic...      False      False
# 339                                 subtribe.The Party          0          0
# 340                                 subtribe.The Chill          0          0
# 341                             subtribe.The Glamorous          0          1
# 342                               subtribe.The Mystery          0          0
# 343                                 subtribe.The Quirk          0          0
# 344                             subtribe.The Adventure          1          0
# 345                                  subtribe.The Cool          0          0
# 346  person_basicdemographics_businessowneroccupati...          0          0
# 347  person_basicdemographics_businessowneroccupati...          0          0
# 348  person_basicdemographics_businessowneroccupati...          0          0
# 349  person_basicdemographics_businessowneroccupati...          0          0
# 350  person_basicdemographics_businessowneroccupati...          0          0
# 351  person_basicdemographics_consumerprominenceind...          0          0
# 352  person_basicdemographics_consumerprominenceind...          0          0
# 353  person_basicdemographics_consumerprominenceind...          0          1
# 354  person_basicdemographics_consumerprominenceind...          1          0
# 355  person_basicdemographics_consumerprominenceind...          0          0
# 356     person_basicdemographics_education.High School          0          0
# 357  person_basicdemographics_education.Vocational/...          0          0
# 358         person_basicdemographics_education.College          0          0
# 359  person_basicdemographics_education.Graduate Sc...          0          1
# 360  person_basicdemographics_employmentstatus.Retired          1          0
# 361  person_basicdemographics_employmentstatus.Full...          0          0
# 362  person_basicdemographics_employmentstatus.Not ...          0          0
# 363  person_basicdemographics_employmentstatus.Part...          0          1
# 364             person_basicdemographics_gender.Female          1          1
# 365               person_basicdemographics_gender.Male          0          0
# 366  person_basicdemographics_maritalstatus.Inferre...          0          0
# 367     person_basicdemographics_maritalstatus.Married          1          1
# 368      person_basicdemographics_maritalstatus.Single          0          0
# 369  person_basicdemographics_maritalstatus.Inferre...          0          0
# 370  person_basicdemographics_occupation.Broker/Sto...          0          0
# 371  person_basicdemographics_occupation.CEO/CFO/Ch...          0          0
# 372  person_basicdemographics_occupation.Account Ex...          0          0
# 373  person_basicdemographics_occupation.Pharmacist...          0          0
# 374        person_basicdemographics_occupation.Cashier          0          0
# 375  person_basicdemographics_occupation.Self Emplo...          0          0
# 376  person_basicdemographics_occupation.Retired/Pe...          0          0
# 377  person_basicdemographics_occupation.Blue Colla...          0          0
# 378  person_basicdemographics_occupation.Self Emplo...          0          0
# 379  person_basicdemographics_occupation.Health Ser...          0          0
# 380  person_basicdemographics_occupation.Navy Credi...          0          0
# 381          person_basicdemographics_occupation.Agent          0          0
# 382      person_basicdemographics_occupation.Homemaker          0          0
# 383   person_basicdemographics_occupation.Chiropractor          0          0
# 384      person_basicdemographics_occupation.President          0          0
# 385          person_basicdemographics_occupation.Pilot          0          0
# 386  person_basicdemographics_occupation.Self Emplo...          0          0
# 387   person_basicdemographics_occupation.Receptionist          0          0
# 388  person_basicdemographics_occupation.Licensed P...          0          0
# 389        person_basicdemographics_occupation.Manager          0          0
# 390  person_basicdemographics_occupation.Registered...          0          0
# 391   person_basicdemographics_occupation.Armed Forces          0          0
# 392         person_basicdemographics_occupation.Broker          0          0
# 393  person_basicdemographics_occupation.Legal/Atto...          1          0
# 394  person_basicdemographics_occupation.Self Emplo...          0          0
# 395  person_basicdemographics_occupation.Middle Man...          0          0
# 396  person_basicdemographics_occupation.Assistant ...          0          0
# 397  person_basicdemographics_occupation.Administra...          0          0
# 398  person_basicdemographics_occupation.Medical Do...          0          0
# 399  person_basicdemographics_occupation.Legal Secr...          0          0
# 400  person_basicdemographics_occupation.Insurance ...          0          0
# 401          person_basicdemographics_occupation.Nurse          0          0
# 402         person_basicdemographics_occupation.Pastor          0          0
# 403    person_basicdemographics_occupation.Electrician          0          0
# 404        person_basicdemographics_occupation.Student          0          0
# 405  person_basicdemographics_occupation.Self Emplo...          0          0
# 406  person_basicdemographics_occupation.Press Oper...          0          0
# 407  person_basicdemographics_occupation.Marketing ...          0          0
# 408  person_basicdemographics_occupation.White Coll...          0          0
# 409  person_basicdemographics_occupation.Self Emplo...          0          0
# 410  person_basicdemographics_occupation.Medical As...          0          0
# 411  person_basicdemographics_occupation.Medical/Pa...          0          0
# 412        person_basicdemographics_occupation.Finance          0          0
# 413  person_basicdemographics_occupation.Self Emplo...          0          0
# 414          person_basicdemographics_occupation.Clerk          0          0
# 415  person_basicdemographics_occupation.General Ma...          0          0
# 416        person_basicdemographics_occupation.Dentist          0          0
# 417      person_basicdemographics_occupation.Secretary          0          0
# 418       person_basicdemographics_occupation.Optician          0          0
# 419       person_basicdemographics_occupation.Operator          0          0
# 420  person_basicdemographics_occupation.Cosmetologist          0          0
# 421          person_basicdemographics_occupation.Sales          0          0
# 422        person_basicdemographics_occupation.Teacher          0          0
# 423  person_basicdemographics_occupation.Self Employed          0          0
# 424   person_basicdemographics_occupation.Professional          0          1
# 425        person_basicdemographics_occupation.Retired          0          0
# 426     person_basicdemographics_occupation.Technician          0          0
# 427       person_basicdemographics_occupation.Engineer          0          0
# 428  person_basicdemographics_occupation.Real Estat...          0          0
# 429  person_basicdemographics_occupation.Executive/...          0          0
# 430         person_basicdemographics_ownerrenter.Owner          1          1
# 431        person_basicdemographics_ownerrenter.Renter          0          0
# 432  household_basicdemographics_adoptionplans.Unli...          0          0
# 433  household_basicdemographics_adoptionplans.Some...          0          0
# 434   household_basicdemographics_adoptionplans.Likely          0          0
# 435  household_basicdemographics_adoptionplans.Very...          1          0
# 436  household_basicdemographics_adoptionplans.Very...          0          1
# 437  household_basicdemographics_adoptionplans.Some...          0          0
# 438  household_basicdemographics_adultsagerange.Mal...          0          0
# 439  household_basicdemographics_adultsagerange.Fem...          0          0
# 440  household_basicdemographics_adultsagerange.Unk...          0          0
# 441  household_basicdemographics_adultsagerange.Mal...          0          0
# 442  household_basicdemographics_adultsagerange.Unk...          0          0
# 443  household_basicdemographics_adultsagerange.Unk...          0          0
# 444  household_basicdemographics_adultsagerange.Fem...          0          1
# 445  household_basicdemographics_adultsagerange.Fem...          0          0
# 446  household_basicdemographics_adultsagerange.Fem...          0          0
# 447  household_basicdemographics_adultsagerange.Mal...          0          0
# 448  household_basicdemographics_adultsagerange.Fem...          0          0
# 449  household_basicdemographics_adultsagerange.Unk...          0          0
# 450  household_basicdemographics_adultsagerange.Mal...          0          0
# 451  household_basicdemographics_adultsagerange.Unk...          0          0
# 452  household_basicdemographics_adultsagerange.Mal...          0          0
# 453  household_basicdemographics_adultsagerange.Mal...          0          1
# 454  household_basicdemographics_adultsagerange.Mal...          0          0
# 455  household_basicdemographics_adultsagerange.Fem...          0          0
# 456  household_basicdemographics_adultsagerange.Fem...          1          0
# 457  household_basicdemographics_babyoradoptionplan...          0          0
# 458  household_basicdemographics_babyoradoptionplan...          0          0
# 459  household_basicdemographics_babyoradoptionplan...          1          1
# 460  household_basicdemographics_babyoradoptionplan...          0          0
# 461  household_basicdemographics_babyoradoptionplan...          0          0
# 462  household_basicdemographics_babyoradoptionplan...          0          0
# 463  household_basicdemographics_babyplans.Somewhat...          0          0
# 464  household_basicdemographics_babyplans.Somewhat...          0          0
# 465  household_basicdemographics_babyplans.Very unl...          0          0
# 466  household_basicdemographics_babyplans.Very likely          0          0
# 467     household_basicdemographics_babyplans.Unlikely          1          1
# 468       household_basicdemographics_babyplans.Likely          0          0
# 469  household_basicdemographics_childrenagerange.M...          0          0
# 470  household_basicdemographics_childrenagerange.U...          0          0
# 471  household_basicdemographics_childrenagerange.M...          0          0
# 472  household_basicdemographics_childrenagerange.F...          0          0
# 473  household_basicdemographics_childrenagerange.U...          0          0
# 474  household_basicdemographics_childrenagerange.U...          0          0
# 475  household_basicdemographics_childrenagerange.M...          0          0
# 476  household_basicdemographics_childrenagerange.F...          0          0
# 477  household_basicdemographics_childrenagerange.F...          0          0
# 478  household_basicdemographics_childrenagerange.U...          0          0
# 479  household_basicdemographics_childrenagerange.F...          0          0
# 480  household_basicdemographics_childrenagerange.U...          0          0
# 481  household_basicdemographics_countryoforigin.Fr...          0          0
# 482  household_basicdemographics_countryoforigin.Po...          0          0
# 483  household_basicdemographics_countryoforigin.Ge...          0          0
# 484  household_basicdemographics_countryoforigin.Italy          0          0
# 485  household_basicdemographics_countryoforigin.Sw...          0          0
# 486  household_basicdemographics_countryoforigin.De...          0          0
# 487  household_basicdemographics_countryoforigin.Hu...          0          0
# 488  household_basicdemographics_countryoforigin.No...          0          0
# 489  household_basicdemographics_countryoforigin.Sl...          0          0
# 490  household_basicdemographics_countryoforigin.Vi...          0          0
# 491  household_basicdemographics_countryoforigin.Uk...          0          0
# 492  household_basicdemographics_countryoforigin.India          0          0
# 493  household_basicdemographics_countryoforigin.Ar...          0          0
# 494  household_basicdemographics_countryoforigin.Hi...          0          0
# 495  household_basicdemographics_countryoforigin.En...          0          1
# 496  household_basicdemographics_countryoforigin.Wales          0          0
# 497  household_basicdemographics_countryoforigin.China          0          0
# 498  household_basicdemographics_countryoforigin.Asian          0          0
# 499  household_basicdemographics_countryoforigin.Fi...          0          0
# 500  household_basicdemographics_countryoforigin.Ir...          0          0
# 501  household_basicdemographics_countryoforigin.Po...          0          0
# 502  household_basicdemographics_countryoforigin.Sc...          1          0
# 503  household_basicdemographics_democraticparty.Ve...          0          0
# 504  household_basicdemographics_democraticparty.So...          0          0
# 505  household_basicdemographics_democraticparty.Un...          0          0
# 506  household_basicdemographics_democraticparty.Ve...          0          1
# 507  household_basicdemographics_democraticparty.Li...          0          0
# 508  household_basicdemographics_democraticparty.So...          1          0
# 509  household_basicdemographics_engagementplans.Ve...          0          0
# 510  household_basicdemographics_engagementplans.Li...          0          0
# 511  household_basicdemographics_engagementplans.Un...          0          0
# 512  household_basicdemographics_engagementplans.So...          0          1
# 513  household_basicdemographics_engagementplans.Ve...          0          0
# 514  household_basicdemographics_engagementplans.So...          1          0
# 515  household_basicdemographics_ethnicity.African ...          0          0
# 516     household_basicdemographics_ethnicity.Hispanic          0          0
# 517  household_basicdemographics_ethnicity.White/Other          1          1
# 518        household_basicdemographics_ethnicity.Asian          0          0
# 519  household_basicdemographics_grandchildplans.Un...          1          1
# 520  household_basicdemographics_grandchildplans.So...          0          0
# 521  household_basicdemographics_grandchildplans.Ve...          0          0
# 522  household_basicdemographics_grandchildplans.So...          0          0
# 523  household_basicdemographics_grandchildplans.Li...          0          0
# 524  household_basicdemographics_grandchildplans.Ve...          0          0
# 525  household_basicdemographics_hispaniclanguagepr...          0          0
# 526  household_basicdemographics_hispaniclanguagepr...          0          0
# 527  household_basicdemographics_hispaniclanguagepr...          1          1
# 528  household_basicdemographics_hispaniclanguagepr...          0          0
# 529  household_basicdemographics_infantagemonths.10-12          0          0
# 530    household_basicdemographics_infantagemonths.7-9          0          0
# 531    household_basicdemographics_infantagemonths.0-6          0          0
# 532  household_basicdemographics_maritalstatus.Infe...          0          0
# 533   household_basicdemographics_maritalstatus.Single          0          0
# 534  household_basicdemographics_maritalstatus.Married          1          1
# 535  household_basicdemographics_maritalstatus.Infe...          0          0
# 536  household_basicdemographics_marriageplans.Some...          0          0
# 537  household_basicdemographics_marriageplans.Some...          0          0
# 538  household_basicdemographics_marriageplans.Unli...          0          0
# 539  household_basicdemographics_marriageplans.Very...          0          0
# 540  household_basicdemographics_marriageplans.Very...          1          1
# 541   household_basicdemographics_marriageplans.Likely          0          0
# 542  household_basicdemographics_newcareerplans.Likely          0          0
# 543  household_basicdemographics_newcareerplans.Som...          0          0
# 544  household_basicdemographics_newcareerplans.Unl...          0          0
# 545  household_basicdemographics_newcareerplans.Ver...          0          0
# 546  household_basicdemographics_newcareerplans.Som...          0          0
# 547  household_basicdemographics_newcareerplans.Ver...          0          0
# 548      household_basicdemographics_ownerrenter.Owner          1          1
# 549     household_basicdemographics_ownerrenter.Renter          0          0
# 550  household_basicdemographics_probableteendriver...          0          0
# 551  household_basicdemographics_probableteendriver...          0          0
# 552  household_basicdemographics_probableteendriver...          0          0
# 553  household_basicdemographics_probableteendriver...          0          0
# 554  household_basicdemographics_probableteendriver...          0          0
# 555  household_basicdemographics_probableteendriver...          0          0
# 556  household_basicdemographics_religiousaffiliati...          0          0
# 557  household_basicdemographics_republicanparty.So...          1          1
# 558  household_basicdemographics_republicanparty.Un...          0          0
# 559  household_basicdemographics_republicanparty.So...          0          0
# 560  household_basicdemographics_republicanparty.Li...          0          0
# 561  household_basicdemographics_republicanparty.Ve...          0          0
# 562  causesandvolunteer_memberofcharitableorganizat...          0          1
# 563  causesandvolunteer_memberofcharitableorganizat...          1          0
# 564  causesandvolunteer_memberofcharitableorganizat...          0          0
# 565  causesandvolunteer_memberofcharitableorganizat...          0          0
# 566  causesandvolunteer_memberofcharitableorganizat...          0          0
# 567  causesandvolunteer_engagedinfundraisingactivit...          0          0
# 568  causesandvolunteer_engagedinfundraisingactivit...          0          0
# 569  causesandvolunteer_engagedinfundraisingactivit...          0          0
# 570  causesandvolunteer_engagedinfundraisingactivit...          1          1
# 571  causesandvolunteer_engagedinfundraisingactivit...          0          0
# 572  causesandvolunteer_engagedinfundraisingactivit...          0          0
# 573  causesandvolunteer_contributetopbs.Somewhat li...          0          0
# 574          causesandvolunteer_contributetopbs.Likely          1          0
# 575  causesandvolunteer_contributetopbs.Somewhat un...          0          0
# 576        causesandvolunteer_contributetopbs.Unlikely          0          0
# 577   causesandvolunteer_contributetopbs.Very unlikely          0          0
# 578     causesandvolunteer_contributetopbs.Very likely          0          1
# 579             political_contactedpolitician.Unlikely          0          0
# 580    political_contactedpolitician.Somewhat unlikely          0          0
# 581          political_contactedpolitician.Very likely          0          0
# 582      political_contactedpolitician.Somewhat likely          1          0
# 583               political_contactedpolitician.Likely          0          1
# 584        political_contactedpolitician.Very unlikely          0          0
# 585            political_democraticparty.Very unlikely          0          0
# 586                   political_democraticparty.Likely          0          0
# 587              political_democraticparty.Very likely          0          1
# 588          political_democraticparty.Somewhat likely          1          0
# 589        political_democraticparty.Somewhat unlikely          0          0
# 590                 political_democraticparty.Unlikely          0          0
# 591                   political_republicanparty.Likely          0          0
# 592          political_republicanparty.Somewhat likely          0          0
# 593                 political_republicanparty.Unlikely          0          0
# 594        political_republicanparty.Somewhat unlikely          1          1
# 595            political_republicanparty.Very unlikely          0          0
# 596      spending_retailpurchasecategories.Oil company          0          0
# 597  spending_retailpurchasecategories.Financial se...          0          0
# 598  spending_retailpurchasecategories.Standard spe...          0          1
# 599             spending_retailpurchasecategories.Misc          0          0
# 600  spending_retailpurchasecategories.Standard ret...          0          0
# 601  spending_retailpurchasecategories.Standard ret...          0          0
# 602  spending_retailpurchasecategories.Financial Se...          0          0
# 603  spending_retailpurchasecategories.Standard spe...          0          0
# 604  spending_retailpurchasecategories.Standard retail          0          1
# 605  spending_retailpurchasecategories.TV/Mail orde...          0          0
# 606  spending_retailpurchasecategories.Standard spe...          0          0
# 607  spending_retailpurchasecategories.Standard spe...          0          1
# 608  spending_retailpurchasecategories.Standard spe...          0          0
# 609  spending_retailpurchasecategories.Standard ret...          0          0
# 610  spending_retailpurchasecategories.Financial se...          0          0
# 611  spending_retailpurchasecategories.Standard spe...          0          0
# 612  spending_retailpurchasecategories.Standard spe...          0          0
# 613  spending_retailpurchasecategories.Upscale spec...          0          0
# 614  spending_retailpurchasecategories.Upscale reta...          0          1
# 615  spending_retailpurchasemostfrequent.Standard r...          0          0
# 616  spending_retailpurchasemostfrequent.Standard r...          0          0
# 617  spending_retailpurchasemostfrequent.Standard s...          0          0
# 618  spending_retailpurchasemostfrequent.Standard r...          0          0
# 619    spending_retailpurchasemostfrequent.Oil company          0          0
# 620  spending_retailpurchasemostfrequent.Standard r...          0          0
# 621  spending_retailpurchasemostfrequent.Standard s...          0          0
# ...
# 737             productpurchase_apparel.Women's casual          0          0
# 738                productpurchase_apparel.Young men's          0          0
# 739                 productpurchase_apparel.Children's          0          0
# 740     productpurchase_foodandbeverage.Food/Beverages          0          0
# 741                          productpurchase_pets.Pets          0          0
# 742  dining_restaurantbrandaffinity_likely.Olive Ga...          0          0
# 743      dining_restaurantbrandaffinity_likely.Chili's          1          0
# 744  dining_restaurantbrandaffinity_likely.TGI Fridays          1          0
# 745    dining_restaurantbrandaffinity_likely.Red Robin          0          0
# 746  dining_restaurantbrandaffinity_unlikely.Red Robin          0          0
# 747  dining_restaurantbrandaffinity_unlikely.Olive ...          0          0
# 748  dining_restaurantbrandaffinity_unlikely.TGI Fr...          0          1
# 749    dining_restaurantbrandaffinity_unlikely.Chili's          0          1
# 750  dining_restaurantbrandaffinity_somewhatlikely....          0          0
# 751  dining_restaurantbrandaffinity_somewhatlikely....          0          0
# 752  dining_restaurantbrandaffinity_somewhatlikely....          0          0
# 753  dining_restaurantbrandaffinity_somewhatlikely....          0          0
# 754  dining_restaurantbrandaffinity_somewhatunlikel...          0          0
# 755  dining_restaurantbrandaffinity_somewhatunlikel...          1          1
# 756  dining_restaurantbrandaffinity_somewhatunlikel...          0          0
# 757  dining_restaurantbrandaffinity_somewhatunlikel...          0          0
# 758  dining_restaurantbrandaffinity_verylikely.Chili's          0          0
# 759  dining_restaurantbrandaffinity_verylikely.Red ...          0          0
# 760  dining_restaurantbrandaffinity_verylikely.Oliv...          0          0
# 761  dining_restaurantbrandaffinity_verylikely.TGI ...          0          0
# 762  dining_restaurantbrandaffinity_veryunlikely.Ol...          1          1
# 763  dining_restaurantbrandaffinity_veryunlikely.Ch...          0          0
# 764  dining_restaurantbrandaffinity_veryunlikely.TG...          0          0
# 765  dining_restaurantbrandaffinity_veryunlikely.Re...          0          0
# 766  dining_restauranttypeaffinity_likely.Casual st...          0          1
# 767  dining_restauranttypeaffinity_unlikely.Casual ...          0          0
# 768  dining_restauranttypeaffinity_somewhatlikely.C...          0          0
# 769  dining_restauranttypeaffinity_somewhatunlikely...          1          0
# 770  dining_restauranttypeaffinity_verylikely.Casua...          0          0
# 771  dining_restauranttypeaffinity_veryunlikely.Cas...          0          0
# 772  mediaconsumption_mediachannelusage_likely.Outdoor          0          0
# 773    mediaconsumption_mediachannelusage_likely.Radio          0          0
# 774  mediaconsumption_mediachannelusage_likely.News...          0          0
# 775  mediaconsumption_mediachannelusage_likely.Dayt...          0          0
# 776  mediaconsumption_mediachannelusage_likely.Cell...          0          0
# 777  mediaconsumption_mediachannelusage_likely.Yell...          0          0
# 778  mediaconsumption_mediachannelusage_likely.Prim...          0          0
# 779  mediaconsumption_mediachannelusage_likely.Inte...          0          0
# 780  mediaconsumption_mediachannelusage_likely.Maga...          0          0
# 781  mediaconsumption_mediachannelusage_unlikely.Da...          1          1
# 782  mediaconsumption_mediachannelusage_unlikely.Ma...          0          0
# 783  mediaconsumption_mediachannelusage_unlikely.Radio          0          0
# 784  mediaconsumption_mediachannelusage_unlikely.Ou...          0          0
# 785  mediaconsumption_mediachannelusage_unlikely.Pr...          1          0
# 786  mediaconsumption_mediachannelusage_unlikely.Ce...          1          1
# 787  mediaconsumption_mediachannelusage_unlikely.In...          0          0
# 788  mediaconsumption_mediachannelusage_unlikely.Ne...          0          0
# 789  mediaconsumption_mediachannelusage_unlikely.Ye...          0          0
# 790  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 791  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 792  mediaconsumption_mediachannelusage_somewhatlik...          1          1
# 793  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 794  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 795  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 796  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 797  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 798  mediaconsumption_mediachannelusage_somewhatlik...          0          0
# 799  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 800  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 801  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 802  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 803  mediaconsumption_mediachannelusage_somewhatunl...          1          1
# 804  mediaconsumption_mediachannelusage_somewhatunl...          1          0
# 805  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 806  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 807  mediaconsumption_mediachannelusage_somewhatunl...          0          0
# 808  mediaconsumption_mediachannelusage_verylikely....          0          0
# 809  mediaconsumption_mediachannelusage_verylikely....          0          0
# 810  mediaconsumption_mediachannelusage_verylikely....          1          1
# 811  mediaconsumption_mediachannelusage_verylikely....          0          0
# 812  mediaconsumption_mediachannelusage_verylikely....          1          1
# 813  mediaconsumption_mediachannelusage_verylikely....          0          0
# 814  mediaconsumption_mediachannelusage_verylikely....          0          0
# 815  mediaconsumption_mediachannelusage_verylikely....          0          0
# 816  mediaconsumption_mediachannelusage_verylikely....          0          0
# 817  mediaconsumption_mediachannelusage_veryunlikel...          0          1
# 818  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 819  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 820  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 821  mediaconsumption_mediachannelusage_veryunlikel...          0          1
# 822  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 823  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 824  mediaconsumption_mediachannelusage_veryunlikel...          0          0
# 825  mediaconsumption_mediachannelusage_veryunlikel...          1          1
# 826  mediaconsumption_tvserviceprovider_likely.DirecTV          0          0
# 827  mediaconsumption_tvserviceprovider_unlikely.Di...          0          0
# 828  mediaconsumption_tvserviceprovider_somewhatlik...          0          0
# 829  mediaconsumption_tvserviceprovider_somewhatunl...          1          0
# 830  mediaconsumption_tvserviceprovider_verylikely....          0          0
# 831  mediaconsumption_tvserviceprovider_veryunlikel...          0          1
# 832  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 833  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 834  shoppingandpurchasechannel_purchaseapparelchan...          1          0
# 835  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 836  shoppingandpurchasechannel_purchaseapparelchan...          1          1
# 837  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 838  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 839  shoppingandpurchasechannel_purchaseapparelchan...          0          1
# 840  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 841  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 842  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 843  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 844  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 845  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 846  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 847  shoppingandpurchasechannel_purchaseapparelchan...          0          0
# 848  shoppingandpurchasechannel_purchaseapparelchan...          1          1
# 849  shoppingandpurchasechannel_purchasechannel_lik...          0          1
# 850  shoppingandpurchasechannel_purchasechannel_lik...          0          1
# 851  shoppingandpurchasechannel_purchasechannel_lik...          1          1
# 852  shoppingandpurchasechannel_purchasechannel_unl...          0          0
# 853  shoppingandpurchasechannel_purchasechannel_unl...          0          0
# 854  shoppingandpurchasechannel_purchasechannel_unl...          0          0
# 855  shoppingandpurchasechannel_purchasechannel_som...          0          0
# 856  shoppingandpurchasechannel_purchasechannel_som...          0          0
# 857  shoppingandpurchasechannel_purchasechannel_som...          1          0
# 858  shoppingandpurchasechannel_purchasechannel_som...          1          0
# 859  shoppingandpurchasechannel_purchasechannel_som...          0          0
# 860  shoppingandpurchasechannel_purchasechannel_som...          0          0
# 861  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 862  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 863  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 864  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 865  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 866  shoppingandpurchasechannel_purchasechannel_ver...          0          0
# 867  shoppingandpurchasechannel_purchasedviainterne...          1          0
# 868  shoppingandpurchasechannel_purchasedviainterne...          0          0
# 869  shoppingandpurchasechannel_purchasedviainterne...          0          1
# 870  shoppingandpurchasechannel_purchasedviainterne...          0          0
# 871  shoppingandpurchasechannel_purchasedviainterne...          0          0
# 872  shoppingandpurchasechannel_purchasedviainterne...          0          0
# 873  shoppingandpurchasechannel_purchaseelectronics...          1          1
# 874  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 875  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 876  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 877  shoppingandpurchasechannel_purchaseelectronics...          1          0
# 878  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 879  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 880  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 881  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 882  shoppingandpurchasechannel_purchaseelectronics...          0          1
# 883  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 884  shoppingandpurchasechannel_purchaseelectronics...          0          0
# 885  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 886  shoppingandpurchasechannel_shoppedforviaintern...          1          1
# 887  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 888  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 889  shoppingandpurchasechannel_shoppedforviaintern...          1          1
# 890  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 891  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 892  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 893  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 894  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 895  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 896  shoppingandpurchasechannel_shoppedforviaintern...          0          0
# 897  shoppingandpurchasechannel_catalogbuyerrecency...          0          0
# 898  shoppingandpurchasechannel_catalogbuyerrecency...          1          1
# 899  shoppingandpurchasechannel_catalogbuyerrecency...          0          0
# 900  shoppingandpurchasechannel_catalogbuyerrecency...          0          0
# 901  shoppingandpurchasechannel_catalogbuyerrecency...          0          0
# 902  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 903  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 904  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 905  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 906  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 907  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 908  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 909  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 910  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 911  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 912  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 913  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 914  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 915  shoppingandpurchasechannel_mailorderbuyercateg...          0          1
# 916  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 917  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 918  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 919  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 920  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 921  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 922  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 923  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 924  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 925  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 926  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 927  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 928  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 929  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 930  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 931  shoppingandpurchasechannel_mailorderbuyercateg...          0          0
# 932              year_spending_firstonlinepurchasedate        NaN       2014
# 933             month_spending_firstonlinepurchasedate        NaN          8
# 934        todayminus_spending_firstonlinepurchasedate        NaN       1836
# 935               year_spending_lastonlinepurchasedate        NaN       2014
# 936              month_spending_lastonlinepurchasedate        NaN          8
# 937         todayminus_spending_lastonlinepurchasedate        NaN       1827
# 938                   year_spending_retailactivitydate        NaN       2014
# 939                  month_spending_retailactivitydate        NaN          4
# 940             todayminus_spending_retailactivitydate        NaN       1963
# 941  year_spending_retailrecentpurchases_retailacti...        NaN       2014
# 942  month_spending_retailrecentpurchases_retailact...        NaN          4
# 943  todayminus_spending_retailrecentpurchases_reta...        NaN       1963

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

model = make_pipeline(IterativeImputer(max_iter=10, random_state=0),
                      LinearDiscriminantAnalysis(n_components = 5, tol = 1.0e-2))

model.fit(x_train, y_train['Assigned Segment'])
predictions = model.predict(x_test)
multi_pred_score_visualizer(y_test['Assigned Segment'],predictions)
# Out:
# C:\Users\zmerritt\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
X_lda2 = lda.transform(x_test)

# %%
model = make_pipeline(RandomForestClassifier(random_state=195))

model.fit(X_lda, y_train['Assigned Segment'])
predictions = model.predict(X_lda2)
#multi_pred_score_visualizer(predictions, model)
# Out:
# C:\Users\zmerritt\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
np.mean(predictions == y_test["Assigned Segment"])
# Out:
# 0.23387096774193547

# %%
predictions = model.predict(x_test)
multi_pred_score_visualizer(predictions, model)
#predictions

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
np.set_printoptions(precision=4)
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
wine = load_wine()
X = pd.DataFrame(wine.data, columns=wine.feature_names)
y = pd.Categorical.from_codes(wine.target, wine.target_names)

# %%
df = X.join(pd.Series(y, name='class'))
df.shape
# Out:
# (178, 14)

# %%
x
# Out:
# array([[ 14.13],
#        [  4.1 ],
#        [  2.74],
#        [ 24.5 ],
#        [ 96.  ],
#        [  2.05],
#        [  0.76],
#        [  0.56],
#        [  1.35],
#        [  9.2 ],
#        [  0.61],
#        [  1.6 ],
#        [560.  ]])

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
X_lda = lda.fit_transform(X, y)

# %%
lda.explained_variance_ratio_
# Out:
# array([0.6875, 0.3125])

# %%
plt.xlabel('LD1')
plt.ylabel('LD2')
plt.scatter(
    X_lda[:,0],
    X_lda[:,1],
    c=y,
    cmap='rainbow',
    alpha=0.7,
    edgecolors='b'
)

# %%
np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]]).shape
# Out:
# (6, 2)
