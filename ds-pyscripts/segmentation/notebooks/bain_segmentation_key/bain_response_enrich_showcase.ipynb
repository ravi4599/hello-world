# %% [markdown]
# ## Load libraries, example data, and .py file

# %%
#load libraries
import pandas as pd
import numpy as np
import sys

#load example data
example_responses = pd.read_csv("../../raw/example_responses.csv", float_precision='round_trip')

#load .py file
sys.path.append('../../progs/')
import bain_response_enrich as bre

# %% [markdown]
# ## Run example

# %% [markdown]
# ### a. input

# %%
example_responses.head()
# Out:
#    UID  I always choose higher end hotels  \
# 0    1                                  5
# 1    2                                  1
# 2    3                                  3
# 3    4                                  3
# 4    5                                  5
#
#    On vacation I pride myself on discovering new places and things my friends have not seen before  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  3
# 4                                                  5
#
#    I choose more expensive hotels and accommodations to make sure I get the best service and amenities  \
# 0                                                  5
# 1                                                  2
# 2                                                  3
# 3                                                  3
# ...

# %% [markdown]
# ### b. output

# %%
bre.bain_response_enrich(example_responses)
# Out:
#    UID  I always choose higher end hotels  \
# 0    1                                  5
# 1    2                                  1
# 2    3                                  3
# 3    4                                  3
# 4    5                                  5
# 5    6                                  5
#
#    On vacation I pride myself on discovering new places and things my friends have not seen before  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  3
# 4                                                  5
# 5                                                  2
#
#    I choose more expensive hotels and accommodations to make sure I get the best service and amenities  \
# 0                                                  5
# 1                                                  2
# ...
